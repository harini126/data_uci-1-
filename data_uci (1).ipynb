# %%
import numpy as np 
import pandas as pd
from sklearn.tree import DecisionTreeClassifier

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
my_data = pd.read_csv("Data_for_UCI_named.csv", delimiter=",")
my_data[0:13]
# Out:
#         tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0   2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1   9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2   8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3   0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4   3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
# 5   6.999209  9.109247  3.784066  4.267788  4.429669 -1.857139 -0.670397
# 6   6.710166  3.765204  6.929314  8.818562  2.397419 -0.614590 -1.208826
# 7   6.953512  1.379125  5.719400  7.870307  3.224495 -0.748998 -1.186517
# 8   4.689852  4.007747  1.478573  3.733787  4.041300 -1.410344 -1.238204
# 9   9.841496  1.413822  9.769856  7.641616  4.727595 -1.991363 -0.857637
# 10  5.930110  6.730873  6.245138  0.533288  2.327092 -0.702501 -1.116920
# 11  5.381299  8.014521  8.095174  6.769248  5.507551 -1.972714 -1.849333
# ...

# %%
my_data=my_data.fillna(0)
my_data.head()
# Out:
#        tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0  2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1  9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2  8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3  0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4  3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
#
#          p4        g1        g2        g3        g4      stab     stabf
# 0 -1.723086  0.650456  0.859578  0.887445  0.958034  0.055347  unstable
# 1 -1.255012  0.413441  0.862414  0.562139  0.781760 -0.005957    stable
# 2 -0.920492  0.163041  0.766689  0.839444  0.109853  0.003471  unstable
# 3 -0.997374  0.446209  0.976744  0.929381  0.362718  0.028871  unstable
# 4 -0.554305  0.797110  0.455450  0.656947  0.820923  0.049860  unstable

# %%
y=my_data['stabf']
y=y.fillna(0)

# %%
x1=my_data['tau1'] 
x1=x1.fillna(0) 
from matplotlib import pyplot as pt 
pt.plot(x1,y)

# %%
x2=my_data['tau2'] 
x2=x2.fillna(0) 
from matplotlib import pyplot as pt 
pt.plot(x2,y)

# %%
x3=my_data['tau3'] 
x3=x3.fillna(0) 
from matplotlib import pyplot as pt 
pt.plot(x3,y)

# %%
x4=my_data['tau4'] 
x4=x4.fillna(0) 
from matplotlib import pyplot as pt 
pt.plot(x4,y)

# %%
x5=my_data['p1'] 
x5=x5.fillna(0) 
from matplotlib import pyplot as pt 
pt.plot(x5,y)

# %%
x6=my_data['p2'] 
x6=x6.fillna(0) 
from matplotlib import pyplot as pt 
pt.plot(x6,y)

# %%
x7=my_data['p3'] 
x7=x7.fillna(0) 
from matplotlib import pyplot as pt 
pt.plot(x7,y)

# %%
x8=my_data['p4'] 
x8=x8.fillna(0) 
from matplotlib import pyplot as pt 
pt.plot(x8,y)

# %%
x9=my_data['g1'] 
x9=x9.fillna(0) 
from matplotlib import pyplot as pt 
pt.plot(x9,y)

# %%
x10=my_data['g2'] 
x10=x10.fillna(0) 
from matplotlib import pyplot as pt 
pt.plot(x10,y)

# %%
x11=my_data['g3'] 
x11=x11.fillna(0) 
from matplotlib import pyplot as pt 
pt.plot(x11,y)

# %%
x12=my_data['g4'] 
x12=x12.fillna(0) 
from matplotlib import pyplot as pt 
pt.plot(x12,y)

# %%
x13=my_data['stab'] 
x13=x13.fillna(0) 
from matplotlib import pyplot as pt 
pt.plot(x13,y)

# %%
X = round(my_data[['tau1','tau2','tau3','tau4','p1','p2','p3','p4','g1','g2','g3','g4','stab']],2).values
X[0:13]
# Out:
# array([[ 2.96,  3.08,  8.38,  9.78,  3.76, -0.78, -1.26, -1.72,  0.65,
#          0.86,  0.89,  0.96,  0.06],
#        [ 9.3 ,  4.9 ,  3.05,  1.37,  5.07, -1.94, -1.87, -1.26,  0.41,
#          0.86,  0.56,  0.78, -0.01],
#        [ 8.97,  8.85,  3.05,  1.21,  3.41, -1.21, -1.28, -0.92,  0.16,
#          0.77,  0.84,  0.11,  0.  ],
#        [ 0.72,  7.67,  4.49,  2.34,  3.96, -1.03, -1.94, -1.  ,  0.45,
#          0.98,  0.93,  0.36,  0.03],
#        [ 3.13,  7.61,  4.94,  9.86,  3.53, -1.13, -1.85, -0.55,  0.8 ,
#          0.46,  0.66,  0.82,  0.05],
#        [ 7.  ,  9.11,  3.78,  4.27,  4.43, -1.86, -0.67, -1.9 ,  0.26,
#          0.08,  0.54,  0.47, -0.02],
#        [ 6.71,  3.77,  6.93,  8.82,  2.4 , -0.61, -1.21, -0.57,  0.18,
#          0.4 ,  0.4 ,  0.38,  0.01],
#        [ 6.95,  1.38,  5.72,  7.87,  3.22, -0.75, -1.19, -1.29,  0.37,
#          0.63,  0.73,  0.38,  0.02],
#        [ 4.69,  4.01,  1.48,  3.73,  4.04, -1.41, -1.24, -1.39,  0.27,
# ...

# %%
from sklearn import preprocessing

# %%
y = my_data["stabf"]
y[0:13]
# Out:
# 0     unstable
# 1       stable
# 2     unstable
# 3     unstable
# 4     unstable
# 5       stable
# 6     unstable
# 7     unstable
# 8       stable
# 9     unstable
# 10      stable
# 11    unstable
# 12      stable
# Name: stabf, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
X_trainset, X_testset, y_trainset, y_testset = train_test_split(X, y, test_size=0.3, random_state=3)

# %%
drugTree = DecisionTreeClassifier(criterion="entropy", max_depth = 4)

# %%
drugTree.fit(X_trainset,y_trainset)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4)

# %%
predTree = drugTree.predict(X_testset)

# %%
print (predTree [0:13])
print (y_testset [0:13])
# Out:
# ['unstable' 'unstable' 'stable' 'stable' 'unstable' 'unstable' 'unstable'
#  'unstable' 'unstable' 'unstable' 'stable' 'unstable' 'stable']
# 5876    unstable
# 6555    unstable
# 1448      stable
# 3351      stable
# 231     unstable
# 1204    unstable
# 1911    unstable
# 9648    unstable
# 8438    unstable
# 7541    unstable
# 2589      stable
# 977     unstable
# 4684    unstable
# Name: stabf, dtype: object

# %%
y_pred = dt_model.predict_proba(X_testset) [:,1]

# %%
new_y = []
for i in range(len(y_pred)):
    if y_pred[i] < 0.4:
       new_y.append(0)
    else:
       new_y.append(1)

# %%
train_accuracy = []
validation_accuracy = []
for depth in range(1,10):
    dt_model = DecisionTreeClassifier(max_depth=depth, random_state=10)
    dt_model.fit(X_trainset,y_trainset)
    train_accuracy.append(dt_model.score(X_trainset, y_trainset))
    validation_accuracy.append(dt_model.score(X_testset, y_testset))

# %%
frame = pd.DataFrame({'max_depth':range(1,10), 'train_acc':train_accuracy, 'valid_acc':validation_accuracy})
frame.head()
# Out:
#    max_depth  train_acc  valid_acc
# 0          1   0.965857   0.967000
# 1          2   0.965857   0.967000
# 2          3   0.967571   0.966000
# 3          4   0.968714   0.965000
# 4          5   0.973286   0.969667

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(figsize=(12,6))
plt.plot(frame['max_depth'], frame['train_acc'], marker='o')
plt.plot(frame['max_depth'], frame['valid_acc'], marker='o')
plt.xlabel('Depth of tree')
plt.ylabel('performance')
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_pred, new_y)

# %%
from sklearn import metrics
import matplotlib.pyplot as plt
print("DecisionTrees's Accuracy: ", metrics.accuracy_score(y_testset, predTree))
# Out:
# DecisionTrees's Accuracy:  0.965

# %%
from io import StringIO

# %%
dt_model = DecisionTreeClassifier(max_depth=13, max_leaf_nodes=13, random_state=10)

# %%
#fitting the model
dt_model.fit(X_trainset, y_trainset)
# Out:
# DecisionTreeClassifier(max_depth=13, max_leaf_nodes=13, random_state=10)

# %%
#training score
dt_model.score(X_trainset, y_trainset)
# Out:
# 0.9755714285714285

# %%
from sklearn import tree
tree.plot_tree(dt_model)
# Out:
# [Text(0.4423076923076923, 0.9375, 'X[12] <= -0.005\ngini = 0.463\nsamples = 7000\nvalue = [2544, 4456]'),
#  Text(0.36538461538461536, 0.8125, 'gini = 0.0\nsamples = 2305\nvalue = [2305, 0]'),
#  Text(0.5192307692307693, 0.8125, 'X[12] <= 0.005\ngini = 0.097\nsamples = 4695\nvalue = [239, 4456]'),
#  Text(0.4423076923076923, 0.6875, 'X[8] <= 0.315\ngini = 0.499\nsamples = 503\nvalue = [239, 264]'),
#  Text(0.23076923076923078, 0.5625, 'X[0] <= 1.505\ngini = 0.47\nsamples = 151\nvalue = [57, 94]'),
#  Text(0.15384615384615385, 0.4375, 'X[10] <= 0.74\ngini = 0.375\nsamples = 16\nvalue = [12, 4]'),
#  Text(0.07692307692307693, 0.3125, 'gini = 0.142\nsamples = 13\nvalue = [12, 1]'),
#  Text(0.23076923076923078, 0.3125, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.3076923076923077, 0.4375, 'gini = 0.444\nsamples = 135\nvalue = [45, 90]'),
#  Text(0.6538461538461539, 0.5625, 'X[2] <= 9.515\ngini = 0.499\nsamples = 352\nvalue = [182, 170]'),
# ...

# %%
# !pip install graphviz

# %%
decision_tree = tree.export_graphviz(dt_model, out_file='tree.dot',feature_names = my_data.columns[0:13], max_depth=10, filled=True)

# %%
# !dot -Tpng tree.dot -o tree.png

# %%
image =plt.imread('tree.png')
plt.figure(figsize=(100,100))
plt.imshow(image)

# %%
# Kernel = linear
from sklearn.svm import SVC
svc = SVC(kernel = 'linear')
svc.fit(X_trainset,y_trainset)
#getting confusion matrix
from sklearn.metrics import confusion_matrix
y_pred_LSVM = svc.predict(X_testset)
cm = confusion_matrix(y_testset,y_pred_LSVM)
print('confusion matrix:\n',cm)
#checking accuracy
from sklearn.metrics import accuracy_score
sva =accuracy_score(y_testset,y_pred_LSVM)
print('accuracy score = ',sva)
# Out:
# confusion matrix:
#  [[ 972  104]
#  [  65 1859]]
# accuracy score =  0.9436666666666667

# %%
# SVM - Kernel -rbf
from sklearn.svm import SVC
svc = SVC(kernel = 'rbf')
svc.fit(X_trainset,y_trainset)
#getting confusion matrix
from sklearn.metrics import confusion_matrix
y_pred_RSVM = svc.predict(X_testset)
cm = confusion_matrix(y_testset,y_pred_RSVM)
print('confusion matrix:\n',cm)
#checking accuracy
from sklearn.metrics import accuracy_score
sva2 = accuracy_score(y_testset,y_pred_RSVM)
print('accuracy score = ',sva2)
# Out:
# confusion matrix:
#  [[ 857  219]
#  [ 121 1803]]
# accuracy score =  0.8866666666666667
